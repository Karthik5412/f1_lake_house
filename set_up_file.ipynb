# %%
# %sql
CREATE CATALOG  IF NOT EXISTS f1_racing

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS f1_racing.bronze;
CREATE SCHEMA IF NOT EXISTS f1_racing.silver;
CREATE SCHEMA IF NOT EXISTS f1_racing.gold;

# %%
# %sql
SHOW DATABASES FROM f1_racing

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS f1_racing.raw_data;
SHOW DATABASES FROM f1_racing
